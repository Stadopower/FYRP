# %%
import pickle
import numpy as np
from continuous_control_bci.util import SUBJECT_IDS

# %% [markdown]
# ### The automaticly detected Frequency peaks

# %%
with open(f'./data/calib_IAFs_dict.pkl', 'rb') as fp1:
    calib_IAFs = pickle.load(fp1)
with open(f'./data/driving_IAFs_dict.pkl', 'rb') as fp2:
    driving_IAFs = pickle.load(fp2)
for i, sub in enumerate(SUBJECT_IDS):
    print(f'Subject {sub} \n calib Filter: {calib_IAFs[i]} \n driving Filter: {driving_IAFs[sub]} \n')
# Out:
# Subject 061
#  calib Filter: [9.0, 11.0]
#  driving Filter: [9.5, 11.5]
#
# Subject 066
#  calib Filter: [10.0, 12.0]
#  driving Filter: [12.0, 14.0]
#
# Subject 126
#  calib Filter: [10.0, 12.0]
#  driving Filter: [10.0, 12.0]
#
# Subject 280
#  calib Filter: [8.0, 10.0]
#  driving Filter: [9.5, 11.5]
#
# Subject 302
#  calib Filter: [11.0, 13.0]
#  driving Filter: [5.0, 7.0]
#
# Subject 336
#  calib Filter: [10.0, 12.0]
#  driving Filter: [5.0, 7.0]
#
# Subject 381
#  calib Filter: [9.0, 11.0]
#  driving Filter: [9.0, 11.0]
#
# Subject 406
#  calib Filter: [10.0, 12.0]
#  driving Filter: [10.5, 12.5]
#
# Subject 530
#  calib Filter: [9.0, 11.0]
#  driving Filter: [5.0, 7.0]
#
# Subject 587
#  calib Filter: [5.0, 7.0]
#  driving Filter: [5.0, 7.0]
#
# Subject 643
#  calib Filter: [10.0, 12.0]
#  driving Filter: [7.5, 9.5]
#
# Subject 656
#  calib Filter: [5.0, 7.0]
#  driving Filter: [5.0, 7.0]
#
# Subject 744
#  calib Filter: [7.0, 9.0]
#  driving Filter: [5.0, 7.0]
#
# Subject 812
#  calib Filter: [9.0, 11.0]
#  driving Filter: [11.0, 13.0]
#
# Subject 840
#  calib Filter: [5.0, 7.0]
#  driving Filter: [5.0, 7.0]
#
# Subject 854
#  calib Filter: [5.0, 7.0]
#  driving Filter: [5.0, 7.0]
#
# Subject 968
#  calib Filter: [10.0, 12.0]
#  driving Filter: [5.0, 7.0]
#
# Subject 986
#  calib Filter: [5.0, 7.0]
#  driving Filter: [5.0, 7.0]

# %% [markdown]
# ## First the results for the three Participants that show good results.

# %%
for subject_id in SUBJECT_IDS:
    with open(f'./data/report_IAF_{subject_id}_binary.pkl', "rb") as fp:
        report = pickle.load(fp)
        print(f"Subject {subject_id}")
        print("IAF Binary:")
        print("Left f1-score", report['Left']["f1-score"])
        print("Right f1-score", report['Right']["f1-score"])
        print("Accuracy f1-score", report['accuracy'])
        print("\n")

    with open(f'./data/driving_report_fb_{subject_id}.pkl', "rb") as fp:
        report = pickle.load(fp)
        #print(f"Subject {subject_id}")
        print("Filter Bank 200ms Widowns:")
        print("Left f1-score", report['Left']["f1-score"])
        print("Right f1-score", report['Right']["f1-score"])
        print("Rest f1-score", report['Rest']["f1-score"])
        print("Accuracy f1-score", report['accuracy'])
        print("\n")

    if subject_id not in ["643", "656", "682", "744", "812", "840", "854", "968", "986"]:
        with open(f'./data/report_sliding_{subject_id}_2s.pkl', "rb") as fp:
            report = pickle.load(fp)
            #print(f"Subject {subject_id}")
            print("2 second Sliding Windows:")
            print("Left f1-score", report['Left']["f1-score"])
            print("Right f1-score", report['Right']["f1-score"])
            print("Rest f1-score", report['Rest']["f1-score"])
            print("Accuracy f1-score", report['accuracy'])
            print("\n")
# Out:
# Subject 061
# IAF Binary:
# Left f1-score 0.8502024291497975
# Right f1-score 0.6824034334763948
# Accuracy f1-score 0.796423658872077
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.05835866261398176
# Right f1-score 0.0
# Rest f1-score 0.6075735138565687
# Accuracy f1-score 0.4389443864619055
#
#
# 2 second Sliding Windows:
# Left f1-score 0.6934244235695987
# Right f1-score 0.6584507042253521
# Rest f1-score 0.5153764581124072
# Accuracy f1-score 0.6234153616703952
#
#
# Subject 066
# IAF Binary:
# Left f1-score 0.8145315487571702
# Right f1-score 0.7155425219941349
# Accuracy f1-score 0.7754629629629629
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.0
# Rest f1-score 0.6471068976789801
# Accuracy f1-score 0.47831339857436267
#
#
# 2 second Sliding Windows:
# Left f1-score 0.02298850574712644
# Right f1-score 0.34426229508196726
# Rest f1-score 0.63881636205396
# Accuracy f1-score 0.49818621523579204
#
#
# Subject 126
# IAF Binary:
# Left f1-score 0.7173637515842839
# Right f1-score 0.721598002496879
# Accuracy f1-score 0.7194968553459119
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.39390073507077333
# Rest f1-score 0.0
# Accuracy f1-score 0.2452530448596717
#
#
# 2 second Sliding Windows:
# Left f1-score 0.4454756380510441
# Right f1-score 0.49756097560975615
# Rest f1-score 0.39583333333333326
# Accuracy f1-score 0.4436033308099924
#
#
# Subject 280
# IAF Binary:
# Left f1-score 0.6810176125244618
# Right f1-score 0.20487804878048782
# Accuracy f1-score 0.5446927374301676
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.031061259706643658
# Right f1-score 0.0
# Rest f1-score 0.6292525707269658
# Accuracy f1-score 0.4611279922922997
#
#
# 2 second Sliding Windows:
# Left f1-score 0.48599819331526645
# Right f1-score 0.29161603888213855
# Rest f1-score 0.21354166666666669
# Accuracy f1-score 0.3491475166790215
#
#
# Subject 302
# IAF Binary:
# Left f1-score 0.6942752740560292
# Right f1-score 0.6270430906389303
# Accuracy f1-score 0.6639892904953146
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.0
# Rest f1-score 0.5945799163634389
# Accuracy f1-score 0.4230620604374372
#
#
# 2 second Sliding Windows:
# Left f1-score 0.14471243042671614
# Right f1-score 0.34177215189873417
# Rest f1-score 0.3655685441020191
# Accuracy f1-score 0.30935808197989173
#
#
# Subject 336
# IAF Binary:
# Left f1-score 0.4821683309557775
# Right f1-score 0.4653902798232696
# Accuracy f1-score 0.47391304347826085
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.009430784776018861
# Rest f1-score 0.4887011928576721
# Accuracy f1-score 0.3240070436313833
#
#
# 2 second Sliding Windows:
# Left f1-score 0.02392344497607655
# Right f1-score 0.0
# Rest f1-score 0.46943396226415096
# Accuracy f1-score 0.30919765166340507
#
#
# Subject 381
# IAF Binary:
# Left f1-score 0.8958566629339305
# Right f1-score 0.8208092485549133
# Accuracy f1-score 0.8682719546742209
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.26903283052351373
# Right f1-score 0.0007339449541284401
# Rest f1-score 0.6145359417652411
# Accuracy f1-score 0.4750231267345051
#
#
# 2 second Sliding Windows:
# Left f1-score 0.6713426853707415
# Right f1-score 0.6396255850234009
# Rest f1-score 0.4586387434554974
# Accuracy f1-score 0.5851966075558982
#
#
# Subject 406
# IAF Binary:
# Left f1-score 0.7091722595078299
# Right f1-score 0.336734693877551
# Accuracy f1-score 0.5956454121306376
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.00154320987654321
# Right f1-score 0.009996155324875047
# Rest f1-score 0.6588896548067236
# Accuracy f1-score 0.49147861764241757
#
#
# 2 second Sliding Windows:
# Left f1-score 0.5599999999999999
# Right f1-score 0.4928229665071771
# Rest f1-score 0.478386167146974
# Accuracy f1-score 0.5153906866614049
#
#
# Subject 530
# IAF Binary:
# Left f1-score 0.532347504621072
# Right f1-score 0.46284501061571126
# Accuracy f1-score 0.5
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.031221303948576674
# Right f1-score 0.022885572139303482
# Rest f1-score 0.5805859277188883
# Accuracy f1-score 0.4116351836829297
#
#
# 2 second Sliding Windows:
# Left f1-score 0.5148741418764302
# Right f1-score 0.1087866108786611
# Rest f1-score 0.4078303425774878
# Accuracy f1-score 0.4206257242178447
#
#
# Subject 587
# IAF Binary:
# Left f1-score 0.5175879396984925
# Right f1-score 0.41818181818181815
# Accuracy f1-score 0.4725274725274725
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.0
# Rest f1-score 0.6481830938210674
# Accuracy f1-score 0.47949029994988907
#
#
# 2 second Sliding Windows:
# Left f1-score 0.42209072978303747
# Right f1-score 0.22307692307692306
# Rest f1-score 0.56120826709062
# Accuracy f1-score 0.4477077363896848
#
#
# Subject 643
# IAF Binary:
# Left f1-score 0.7678391959798995
# Right f1-score 0.42105263157894735
# Accuracy f1-score 0.6685796269727403
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.0
# Rest f1-score 0.6491846184819811
# Accuracy f1-score 0.4805872270661003
#
#
# Subject 656
# IAF Binary:
# Left f1-score 0.7027559055118109
# Right f1-score 0.1748633879781421
# Accuracy f1-score 0.5629522431259045
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.00048804294777940455
# Right f1-score 0.0014209591474245115
# Rest f1-score 0.661270542065244
# Accuracy f1-score 0.4940288665836325
#
#
# Subject 744
# IAF Binary:
# Left f1-score 0.6123936816524909
# Right f1-score 0.27990970654627545
# Accuracy f1-score 0.4960505529225908
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.0
# Rest f1-score 0.6533026618468617
# Accuracy f1-score 0.4851146900927282
#
#
# Subject 812
# IAF Binary:
# Left f1-score 0.6720430107526881
# Right f1-score 0.6839378238341969
# Accuracy f1-score 0.6781002638522428
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.1278312131554452
# Right f1-score 0.002468373958654736
# Rest f1-score 0.5744113968789082
# Accuracy f1-score 0.40586936391480877
#
#
# Subject 840
# IAF Binary:
# Left f1-score 0.6301115241635689
# Right f1-score 0.3761755485893417
# Accuracy f1-score 0.5355892648774796
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.0
# Rest f1-score 0.6879760906804679
# Accuracy f1-score 0.5243624645813656
#
#
# Subject 854
# IAF Binary:
# Left f1-score 0.5376044568245126
# Right f1-score 0.44666666666666666
# Accuracy f1-score 0.496206373292868
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0014866204162537165
# Right f1-score 0.0007686395080707148
# Rest f1-score 0.6724103782927313
# Accuracy f1-score 0.5063725124841619
#
#
# Subject 968
# IAF Binary:
# Left f1-score 0.3992932862190813
# Right f1-score 0.5674300254452926
# Accuracy f1-score 0.4970414201183432
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.0
# Rest f1-score 0.6388755277644167
# Accuracy f1-score 0.46937333123920216
#
#
# Subject 986
# IAF Binary:
# Left f1-score 0.4781849912739965
# Right f1-score 0.5364341085271317
# Accuracy f1-score 0.5090311986863711
#
#
# Filter Bank 200ms Widowns:
# Left f1-score 0.0
# Right f1-score 0.0
# Rest f1-score 0.6933696090286174
# Accuracy f1-score 0.5306547389527262

# %%
for subject_id in ['061', '381', '812']:
    print(f"Subject {subject_id}: ")
    with open(f'./data/report_sliding_{subject_id}_2s.pkl', "rb") as fp:
        report = pickle.load(fp)
        print("Sliding Window:")
        print("\t Left f1-score", report['Left']["f1-score"])
        print("\t Right f1-score", report['Right']["f1-score"])
        print("\t Rest f1-score", report['Rest']["f1-score"])
        print("\t Accuracy f1-score", report['accuracy'])

    with open(f'./data/report_IAF_{subject_id}_1.pkl', "rb") as fp:
        report = pickle.load(fp)
        print("IAF:")
        print("\t Left f1-score", report['Left']["f1-score"])
        print("\t Right f1-score", report['Right']["f1-score"])
        print("\t Rest f1-score", report['Rest']["f1-score"])
        print("\t Accuracy f1-score", report['accuracy'])

    with open(f'./data/report_IAF_{subject_id}_binary.pkl', "rb") as fp:
        report = pickle.load(fp)
        print("IAF Binary:")
        print("\t Left f1-score", report['Left']["f1-score"])
        print("\t Right f1-score", report['Right']["f1-score"])
        print("\t Accuracy f1-score", report['accuracy'])

    with open(f'./data/train_test_reversed_IAF_{subject_id}.pkl', "rb") as fp:
        report = pickle.load(fp)
        print("Training on Driving, Testing on Calib IAF:")
        print("\t Left f1-score", report['Left']["f1-score"])
        print("\t Right f1-score", report['Right']["f1-score"])
        print("\t Rest f1-score", report['Rest']["f1-score"])
        print("\t Accuracy f1-score", report['accuracy'])

    with open(f'./data/driving_report_fb_{subject_id}.pkl', "rb") as fp:
        report = pickle.load(fp)
        print("Filter Bank:")
        print("\t Left f1-score", report['Left']["f1-score"])
        print("\t Right f1-score", report['Right']["f1-score"])
        print("\t Rest f1-score", report['Rest']["f1-score"])
        print("\t Accuracy f1-score", report['accuracy'])




    print("\n")
# Out:
# Subject 061:
# Sliding Window:
# 	 Left f1-score 0.6934244235695987
# 	 Right f1-score 0.6584507042253521
# 	 Rest f1-score 0.5153764581124072
# 	 Accuracy f1-score 0.6234153616703952
# IAF:
# 	 Left f1-score 0.6734534064213
# 	 Right f1-score 0.6993464052287582
# 	 Rest f1-score 0.3959646910466583
# 	 Accuracy f1-score 0.5973154362416108
# IAF Binary:
# 	 Left f1-score 0.8502024291497975
# 	 Right f1-score 0.6824034334763948
# 	 Accuracy f1-score 0.796423658872077
# Training on Driving, Testing on Calib IAF:
# 	 Left f1-score 0.4615384615384615
# 	 Right f1-score 0.6874999999999999
# 	 Rest f1-score 0.7843137254901961
# 	 Accuracy f1-score 0.7125
# Filter Bank:
# 	 Left f1-score 0.05835866261398176
# 	 Right f1-score 0.0
# 	 Rest f1-score 0.6075735138565687
# 	 Accuracy f1-score 0.4389443864619055
#
#
# Subject 381:
# Sliding Window:
# 	 Left f1-score 0.6713426853707415
# 	 Right f1-score 0.6396255850234009
# 	 Rest f1-score 0.4586387434554974
# 	 Accuracy f1-score 0.5851966075558982
# IAF:
# 	 Left f1-score 0.6971637694419031
# 	 Right f1-score 0.6593059936908517
# 	 Rest f1-score 0.41291810841983856
# 	 Accuracy f1-score 0.5929067077872012
# IAF Binary:
# 	 Left f1-score 0.8958566629339305
# 	 Right f1-score 0.8208092485549133
# 	 Accuracy f1-score 0.8682719546742209
# Training on Driving, Testing on Calib IAF:
# 	 Left f1-score 0.6206896551724138
# 	 Right f1-score 0.7222222222222223
# 	 Rest f1-score 0.7789473684210527
# 	 Accuracy f1-score 0.7375
# Filter Bank:
# 	 Left f1-score 0.26903283052351373
# 	 Right f1-score 0.0007339449541284401
# 	 Rest f1-score 0.6145359417652411
# 	 Accuracy f1-score 0.4750231267345051
#
#
# Subject 812:
# Sliding Window:
# 	 Left f1-score 0.4774535809018568
# 	 Right f1-score 0.6348733233979136
# 	 Rest f1-score 0.5749456915278783
# 	 Accuracy f1-score 0.5630791161796151
# IAF:
# 	 Left f1-score 0.4972222222222221
# 	 Right f1-score 0.6324237560192616
# 	 Rest f1-score 0.6233766233766235
# 	 Accuracy f1-score 0.5930149679258732
# IAF Binary:
# 	 Left f1-score 0.6720430107526881
# 	 Right f1-score 0.6839378238341969
# 	 Accuracy f1-score 0.6781002638522428
# Training on Driving, Testing on Calib IAF:
# 	 Left f1-score 0.2608695652173913
# 	 Right f1-score 0.0
# 	 Rest f1-score 0.6896551724137931
# 	 Accuracy f1-score 0.5375
# Filter Bank:
# 	 Left f1-score 0.1278312131554452
# 	 Right f1-score 0.002468373958654736
# 	 Rest f1-score 0.5744113968789082
# 	 Accuracy f1-score 0.40586936391480877

# %% [markdown]
# There is no real gain from one method to another, The filter bank approach does not work at all this is probably because the epochs are only 200ms long.
